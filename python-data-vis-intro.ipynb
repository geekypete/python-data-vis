# %% [markdown]
# # Introduction to Python for Data Visualization
# ![pythonfigs](https://www.datasciencesociety.net/wp-content/uploads/2019/04/Bokeh_Introduction.jpg)

# %% [markdown]
# # What is data visualization?

# %% [markdown]
# ## <span style="color:#2874A6">Data visualization</span> <span style="color:#585858">is the graphic representation of data</span>

# %% [markdown]
# ## <span style="color:#585858">Graphics _reveal_ data</span>

# %% [markdown]
# <blockquote>“There is a magic in graphs. The proﬁle of a curve reveals in a ﬂash a whole situation — the life history of an epidemic, a panic, or an era of prosperity. The curve informs the mind, awakens the imagination, convinces.” - Henry D. Hubbard</blockquote>

# %%
import seaborn as sns
#sns.set(font_scale=2)
sns.set(style="ticks", font_scale=1.5)
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
plot = sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="colorblind", height=5,
           scatter_kws={"s": 100, "alpha": 1},line_kws={'lw': 3})

# %% [markdown]
# ![Datasaur Summary Statistics](https://miro.medium.com/max/354/1*WGOjHSOJAuVfGfySmHzJSA.png)

# %% [markdown]
# <img src="./carbon.png" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# ![Datasaurus](https://miro.medium.com/max/750/1*W--cGoA3_n2ZlU6Xs4o2iQ.gif)

# %% [markdown]
# ## Anscombe's Quartet
#
# <img src="https://miro.medium.com/max/729/1*JyDU5qgFA-S2XOFBah9YcQ.png" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="color:#585858">Establishing a</span>

# %% [markdown]
# # Vocabulary of Vision

# %% [markdown]
# ###  <span style="color:#585858">_Sémiologie graphique_ - Jacques Bertin</span>
# ### <span style="color:#585858">1967</span>
# ![Sémiologie graphique cover](https://images-na.ssl-images-amazon.com/images/I/41SVS6TG2KL._SX358_BO1,204,203,200_.jpg)

# %% [markdown]
# In 1967 French cartographer and theorist of information graphics Jacques Bertin published Sémiologie graphique. Les diagrammes, les réseaux, les cartes in Paris at the press of Gauthier-Villars. This book provided the first theoretical foundation for information graphics: a systematic classification of the use of visual elements to display data and relationships, primarily in static graphics. Bertin's system consisted of seven visual variables: position, form (shape), orientation, color (hue), texture, value (lightness or darkness of color), and size, combined with a visual semantics for linking data attributes to visual elements.

# %% [markdown]
# # Preattentive attributes of visual perception
# * Form
# * Color
# * Spatial Position
# * Motion

# %% [markdown]
# # Preattentive attributes of visual perception
# ![Preattentive attributes](https://help.tableau.com/current/blueprint/en-us/Img/bp_why_visual_analytics.png)

# %% [markdown]
# ![preattentive-nine](https://thevideoanalyst.com/wp-content/uploads/2019/03/count-the-9s-grey.png)

# %% [markdown]
# ![preattentive-nine-highlight](https://thevideoanalyst.com/wp-content/uploads/2019/03/count-the-9s-colour.png)

# %% [markdown]
# ## <span style="color:#585858">Establishing a</span>

# %% [markdown]
# # Grammar of Graphics

# %% [markdown]
# ### <span style="color:#585858"> _The Grammar of Graphics_ - Leland Wilkinson</span>
# ![Grammar of Graphics Cover](https://images-na.ssl-images-amazon.com/images/I/41U%2BsQQraoL._SX329_BO1,204,203,200_.jpg)

# %% [markdown]
# ![Grammar of Graphics Visualization](https://miro.medium.com/max/3840/1*mcLnnVdHNg-ikDbHJfHDNA.png)

# %% [markdown]
# # Why Python for Data Visualization?

# %% [markdown]
# ## <span style="color:#585858">Ease of Use</span>

# %% [markdown]
# ## <span style="color:#585858">Extensive Visualization Libraries</span>

# %% [markdown]
# ## <span style="color:#585858">Multi-purpose</span>

# %% [markdown]
# ## <span style="color:#585858">Community</span>
