# %% [markdown]
# # Welcome to Introduction to Python for Data Visualization

# %% [markdown]
# # What is data visualization?

# %% [markdown]
# # Why Python for Data Visualization?

# %%
import seaborn as sns
#sns.set(font_scale=2)
sns.set(style="ticks", font_scale=1.5)


# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
plot = sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=5,
           scatter_kws={"s": 100, "alpha": 1},line_kws={'lw': 3})

# %% [markdown]
# ## Anscombe's Quartet
# ![Anscombe](https://miro.medium.com/max/729/1*JyDU5qgFA-S2XOFBah9YcQ.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
grouped_df = df.groupby('dataset')

for key, item in grouped_df:
    print(grouped_df.get_group(key), "\n\n")
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
#
#
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74
#
#
#    dataset     x      y
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
#
#
#    dataset     x      y
# 33      IV   8.0   6.58
# ...

# %%
print(df.groupby('dataset').describe().unstack(1))
# Out:
#           dataset
# x  count  I          11.00
#           II         11.00
#           III        11.00
#           IV         11.00
#    mean   I           9.00
#                      ...
# y  75%    IV          8.19
#    max    I          10.84
#           II          9.26
#           III        12.74
#           IV         12.50
# Length: 64, dtype: float64

# %%
print(grouped_df.get_group('II'))
# Out:
#    dataset     x     y
# 11      II  10.0  9.14
# 12      II   8.0  8.14
# 13      II  13.0  8.74
# 14      II   9.0  8.77
# 15      II  11.0  9.26
# 16      II  14.0  8.10
# 17      II   6.0  6.13
# 18      II   4.0  3.10
# 19      II  12.0  9.13
# 20      II   7.0  7.26
# 21      II   5.0  4.74

# %% [markdown]
# # Preattentive attributes of visual perception
# ![Preattentive attributes](https://help.tableau.com/current/blueprint/en-us/Img/bp_why_visual_analytics.png)
